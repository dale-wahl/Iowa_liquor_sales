# %%
import pandas as pd
BIGMERGE = pd.read_csv('iowa_gist.csv', index_col='Unnamed: 0')

# %%
BIGMERGE.columns
# Out:
# Index(['Year', 'Month', 'Store Number', 'Bottle Volume (ml)', 'Bottles Sold',
#        'Sale (Dollars)', 'Volume Sold (Liters)', 'Volume Sold (Gallons)',
#        'City', 'State Bottle Cost', 'State Bottle Retail', '2010_pop',
#        '2015_pop_est', '2016_pop_est', 'Monthly Stores in City',
#        'Pop per Store'],
#       dtype='object')

# %%
BIGMERGE.head()
# Out:
#    Year  Month  Store Number  Bottle Volume (ml)  Bottles Sold  \
# 0  2015      1          2106            354975.0        7580.0
# 1  2015      1          2113            116750.0         571.0
# 2  2015      1          2130            279925.0        4831.0
# 3  2015      1          2152            123500.0         477.0
# 4  2015      1          2178            183425.0        1500.0
#
#    Sale (Dollars)  Volume Sold (Liters)  Volume Sold (Gallons)         City  \
# 0       109795.48               7116.85                1880.39  CEDAR FALLS
# 1         7685.86                566.74                 149.68       GOWRIE
# 2        71307.51               4338.05                1146.09     WATERLOO
# 3         5746.27                484.86                 128.07     ROCKWELL
# 4        17970.36               1454.70                 384.29       WAUKON
#
#    State Bottle Cost  State Bottle Retail  2010_pop  2015_pop_est  \
# ...
